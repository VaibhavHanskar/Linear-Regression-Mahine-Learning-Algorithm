# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
del df['date']

# %%
del df['street']

# %%
del df['city']

# %%
del df['statezip']

# %%
del df['country']

# %%
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
#  x1 = df.iloc[:,1].values.reshape(-1,1)

# %%
#  x1

# %%
# x2 = df.iloc[:,2].values.reshape(-1,1)

# %%
# x2

# %%
# x3 = df.iloc[:,3].values.reshape(-1,1)

# %%
# x3

# %%
# x4 = df.iloc[:,4].values.reshape(-1,1)

# %%
# x4

# %%
# x9= df.iloc[:,9].values.reshape(-1,1)

# %%
# x9

# %%
# x10 = df.iloc[:,10].values.reshape(-1,1)

# %%
# x10

# %%
# x11 = df.iloc[:,11].values.reshape(-1,1)

# %%
# x11

# %%
# x12 = df.iloc[:,12].values.reshape(-1,1)

# %%
# x12

# %%
x = df.iloc[:,1:].values

# %%
x
# Out:
# array([[3.000e+00, 1.500e+00, 1.340e+03, ..., 0.000e+00, 1.955e+03,
#         2.005e+03],
#        [5.000e+00, 2.500e+00, 3.650e+03, ..., 2.800e+02, 1.921e+03,
#         0.000e+00],
#        [3.000e+00, 2.000e+00, 1.930e+03, ..., 0.000e+00, 1.966e+03,
#         0.000e+00],
#        ...,
#        [3.000e+00, 2.500e+00, 3.010e+03, ..., 0.000e+00, 2.009e+03,
#         0.000e+00],
#        [4.000e+00, 2.000e+00, 2.090e+03, ..., 1.020e+03, 1.974e+03,
#         0.000e+00],
#        [3.000e+00, 2.500e+00, 1.490e+03, ..., 0.000e+00, 1.990e+03,
#         0.000e+00]])

# %%
y = df.iloc[:,0].values

# %%
y
# Out:
# array([ 313000.      , 2384000.      ,  342000.      , ...,
#         416904.166667,  203400.      ,  220600.      ])

# %%
from sklearn.model_selection import train_test_split

# %%
# x_train = x1_train,x2_train,x3_train,x4_train,x9_train,x10_train,x11_train

# %%
# x_test =x1_test,x2_test,x3_test,x4_test,x9_test,x10_test,x11_test

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.20,random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
y_pred
# Out:
# array([ 509531.73334973,  631403.61913727,  245699.02163352,
#         575057.46768666,  776352.89813186,  286065.15959556,
#         603360.1576946 ,  616276.1442418 ,  350561.71471842,
#        1336770.87332658,  587838.26192152,  446844.46842095,
#        1024008.46565529,  538744.55839863,  600835.80292685,
#         289312.67698769,  375678.04081206,  466786.05807093,
#         941333.06911325,  370734.30425276,  421342.69998008,
#         910449.85636337,  371470.42632192,  412855.53527861,
#         720113.49599693,  436688.20671142,  636335.06798852,
#         612757.01082834,  263803.89113819,  615749.53155079,
#         734364.45648785,  487217.32678685,  515257.13387396,
#         546046.12506498,  388985.16966014,  468707.68157388,
#         351710.6697909 ,  415414.61154428,  409760.57232127,
#         584723.48823141,  605253.65142945,  412533.5141789 ,
#         504292.3907259 ,  798255.02443324,  404320.50054599,
# ...

# %%
z = y_test - y_pred

# %%
z
# Out:
# array([-2.20531733e+05, -2.01503619e+05, -1.16699022e+05,  2.49425323e+04,
#         5.21647102e+05, -1.38065160e+05, -2.06860158e+05, -1.66276144e+05,
#        -6.06171472e+03, -8.67708733e+04, -1.37038262e+05,  1.33155532e+05,
#        -2.40084657e+04,  2.62554416e+04, -2.60845803e+05, -1.14312677e+05,
#         4.54321959e+05, -5.67860581e+04,  6.38666931e+05, -1.85734304e+05,
#         6.36573000e+04, -2.10449856e+05, -3.35246763e+04, -5.78555353e+04,
#        -1.15113496e+05, -1.66882067e+04, -6.36335068e+05,  1.22429892e+04,
#        -5.88038911e+04, -1.15799532e+05,  2.75635544e+05, -1.24173268e+04,
#         2.76742866e+05,  1.33953875e+05,  4.60148303e+04,  6.19231843e+03,
#        -1.97106698e+04, -1.56414612e+05,  2.80239428e+05, -5.47234882e+04,
#        -2.15253651e+05, -4.35335142e+04, -9.82298907e+04,  1.64744976e+05,
#         2.00679499e+05, -5.86493421e+04, -3.68867245e+05,  8.83550956e+04,
# ...

# %%
reg.coef_
# Out:
# array([-5.87984645e+04,  6.62944843e+04,  1.59342738e+02, -6.75122633e-01,
#         3.26880015e+04,  3.02689414e+05,  4.52571605e+04,  3.38848789e+04,
#         8.76237239e+01,  7.17190141e+01, -2.27561204e+03,  6.67723595e+00])

# %%
reg.intercept_
# Out:
# 4395948.751375914

# %%
from sklearn import metrics

# %%
acc = metrics.r2_score(y_test,y_pred)

# %%
acc *100
# Out:
# 54.88458079132712
